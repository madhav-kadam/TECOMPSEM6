# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("world_population_data.csv")

# %%
df.shape
# Out:
# (234, 17)

# %%
df.describe()
# Out:
#              rank  2023 population  2022 population  2020 population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.437442e+07     3.407441e+07     3.350107e+07
# std     67.694165     1.373864e+08     1.367664e+08     1.355899e+08
# min      1.000000     5.180000e+02     5.100000e+02     5.200000e+02
# 25%     59.250000     4.225982e+05     4.197385e+05     4.152845e+05
# 50%    117.500000     5.643895e+06     5.559944e+06     5.493074e+06
# 75%    175.750000     2.324537e+07     2.247650e+07     2.144798e+07
# max    234.000000     1.428628e+09     1.425887e+09     1.424930e+09
#
#        2015 population  2010 population  2000 population  1990 population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      3.172996e+07     2.984524e+07     2.626947e+07     2.271022e+07
# std       1.304050e+08     1.242185e+08     1.116982e+08     9.783217e+07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rank              234 non-null    int64
#  1   cca3              234 non-null    object
#  2   country           234 non-null    object
#  3   continent         234 non-null    object
#  4   2023 population   234 non-null    int64
#  5   2022 population   234 non-null    int64
#  6   2020 population   234 non-null    int64
#  7   2015 population   234 non-null    int64
#  8   2010 population   234 non-null    int64
#  9   2000 population   234 non-null    int64
#  10  1990 population   234 non-null    int64
#  11  1980 population   234 non-null    int64
#  12  1970 population   234 non-null    int64
#  13  area (km²)        234 non-null    float64
#  14  density (km²)     234 non-null    int64
#  15  growth rate       234 non-null    object
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=234, step=1)

# %%
df.columns
# Out:
# Index(['rank', 'cca3', 'country', 'continent', '2023 population',
#        '2022 population', '2020 population', '2015 population',
#        '2010 population', '2000 population', '1990 population',
#        '1980 population', '1970 population', 'area (km²)', 'density (km²)',
#        'growth rate', 'world percentage'],
#       dtype='object')

# %%
df.dtypes
# Out:
# rank                  int64
# cca3                 object
# country              object
# continent            object
# 2023 population       int64
# 2022 population       int64
# 2020 population       int64
# 2015 population       int64
# 2010 population       int64
# 2000 population       int64
# 1990 population       int64
# 1980 population       int64
# 1970 population       int64
# area (km²)          float64
# density (km²)         int64
# growth rate          object
# world percentage     object
# dtype: object

# %%
df.columns.values
# Out:
# array(['rank', 'cca3', 'country', 'continent', '2023 population',
#        '2022 population', '2020 population', '2015 population',
#        '2010 population', '2000 population', '1990 population',
#        '1980 population', '1970 population', 'area (km²)',
#        'density (km²)', 'growth rate', 'world percentage'], dtype=object)

# %%
df
# Out:
#      rank cca3           country      continent  2023 population  \
# 0       1  IND             India           Asia       1428627663
# 1       2  CHN             China           Asia       1425671352
# 2       3  USA     United States  North America        339996563
# 3       4  IDN         Indonesia           Asia        277534122
# 4       5  PAK          Pakistan           Asia        240485658
# ..    ...  ...               ...            ...              ...
# 229   230  MSR        Montserrat  North America             4386
# 230   231  FLK  Falkland Islands  South America             3791
# 231   232  NIU              Niue        Oceania             1935
# 232   233  TKL           Tokelau        Oceania             1893
# 233   234  VAT      Vatican City         Europe              518
#
#      2022 population  2020 population  2015 population  2010 population  \
# 0         1417173173       1396387127       1322866505       1240613620
# ...

# %%
df.head()
# Out:
#    rank cca3        country      continent  2023 population  2022 population  \
# 0     1  IND          India           Asia       1428627663       1417173173
# 1     2  CHN          China           Asia       1425671352       1425887337
# 2     3  USA  United States  North America        339996563        338289857
# 3     4  IDN      Indonesia           Asia        277534122        275501339
# 4     5  PAK       Pakistan           Asia        240485658        235824862
#
#    2020 population  2015 population  2010 population  2000 population  \
# 0       1396387127       1322866505       1240613620       1059633675
# 1       1424929781       1393715448       1348191368       1264099069
# 2        335942003        324607776        311182845        282398554
# 3        271857970        259091970        244016173        214072421
# 4        227196741        210969298        194454498        154369924
#
#    1990 population  1980 population  1970 population  area (km²)  \
# ...

# %%
df.tail()
# Out:
#      rank cca3           country      continent  2023 population  \
# 229   230  MSR        Montserrat  North America             4386
# 230   231  FLK  Falkland Islands  South America             3791
# 231   232  NIU              Niue        Oceania             1935
# 232   233  TKL           Tokelau        Oceania             1893
# 233   234  VAT      Vatican City         Europe              518
#
#      2022 population  2020 population  2015 population  2010 population  \
# 229             4390             4500             5059             4938
# 230             3780             3747             3408             3187
# 231             1934             1942             1847             1812
# 232             1871             1827             1454             1367
# 233              510              520              564              596
#
#      2000 population  1990 population  1980 population  1970 population  \
# ...

# %%
df1=df.loc[:,["rank","country"]]

# %%
df1
# Out:
#      rank           country
# 0       1             India
# 1       2             China
# 2       3     United States
# 3       4         Indonesia
# 4       5          Pakistan
# ..    ...               ...
# 229   230        Montserrat
# 230   231  Falkland Islands
# 231   232              Niue
# 232   233           Tokelau
# 233   234      Vatican City
#
# [234 rows x 2 columns]

# %%
df.sort_values(by="country")
# Out:
#      rank cca3            country continent  2023 population  2022 population  \
# 35     36  AFG        Afghanistan      Asia         42239854         41128771
# 137   138  ALB            Albania    Europe          2832439          2842321
# 33     34  DZA            Algeria    Africa         45606480         44903225
# 213   214  ASM     American Samoa   Oceania            43914            44273
# 202   203  AND            Andorra    Europe            80088            79824
# ..    ...  ...                ...       ...              ...              ...
# 225   226  WLF  Wallis and Futuna   Oceania            11502            11572
# 171   172  ESH     Western Sahara    Africa           587259           575986
# 43     44  YEM              Yemen      Asia         34449825         33696614
# 62     63  ZMB             Zambia    Africa         20569737         20017675
# 73     74  ZWE           Zimbabwe    Africa         16665409         16320537
#
# ...

# %%
df1.sort_values(by="country")
# Out:
#      rank            country
# 35     36        Afghanistan
# 137   138            Albania
# 33     34            Algeria
# 213   214     American Samoa
# 202   203            Andorra
# ..    ...                ...
# 225   226  Wallis and Futuna
# 171   172     Western Sahara
# 43     44              Yemen
# 62     63             Zambia
# 73     74           Zimbabwe
#
# [234 rows x 2 columns]

# %%
df1.hist()
# Out:
# array([[<Axes: title={'center': 'rank'}>]], dtype=object)

# %%
df.head().hist()
# Out:
# array([[<Axes: title={'center': 'rank'}>,
#         <Axes: title={'center': '2023 population'}>,
#         <Axes: title={'center': '2022 population'}>],
#        [<Axes: title={'center': '2020 population'}>,
#         <Axes: title={'center': '2015 population'}>,
#         <Axes: title={'center': '2010 population'}>],
#        [<Axes: title={'center': '2000 population'}>,
#         <Axes: title={'center': '1990 population'}>,
#         <Axes: title={'center': '1980 population'}>],
#        [<Axes: title={'center': '1970 population'}>,
#         <Axes: title={'center': 'area (km²)'}>,
#         <Axes: title={'center': 'density (km²)'}>]], dtype=object)

# %%
df1.head().sort_values(by="country").hist()
# Out:
# array([[<Axes: title={'center': 'rank'}>]], dtype=object)

# %%
df1.head().hist()
# Out:
# array([[<Axes: title={'center': 'rank'}>]], dtype=object)

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.head().plot()
# Out:
# <Axes: >

# %%
sns.displot()

# %%
df2=df.iloc[:3, :5]

# %%
df2
# Out:
#    rank cca3        country      continent  2023 population
# 0     1  IND          India           Asia       1428627663
# 1     2  CHN          China           Asia       1425671352
# 2     3  USA  United States  North America        339996563

# %%
df[3:15]
# Out:
#     rank cca3      country      continent  2023 population  2022 population  \
# 3      4  IDN    Indonesia           Asia        277534122        275501339
# 4      5  PAK     Pakistan           Asia        240485658        235824862
# 5      6  NGA      Nigeria         Africa        223804632        218541212
# 6      7  BRA       Brazil  South America        216422446        215313498
# 7      8  BGD   Bangladesh           Asia        172954319        171186372
# 8      9  RUS       Russia         Europe        144444359        144713314
# 9     10  MEX       Mexico  North America        128455567        127504125
# 10    11  ETH     Ethiopia         Africa        126527060        123379924
# 11    12  JPN        Japan           Asia        123294513        123951692
# 12    13  PHL  Philippines           Asia        117337368        115559009
# 13    14  EGY        Egypt         Africa        112716598        110990103
# ...
